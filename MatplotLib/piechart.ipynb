# %% [markdown]
#                                                                         MATPLOTLIB PIECHART

# %% [markdown]
# '''<br>
# @Author: Rahul <br>
# @Date: 2024-08-19<br>
# @Last Modified by: Rahul <br>
# @Last Modified time: 2024-08-19<br>
# @Title: Python program for Matplotlib build-In functions for pie-chart <br>
# '''

# %%
import matplotlib.pyplot as mp
import pandas as pd

# %% [markdown]
# 1. Write a Python programming to create a pie chart of the popularity of programming
# Languages.

# %%
def createChart(labels,sizes):

    """

    Description:
        Creates and displays a pie chart based on the given labels and sizes.
    Parameters:
        labels (list of str): A list of labels for each slice of the pie chart.
        sizes (list of float): A list of sizes corresponding to each label, typically representing proportions or percentages.
    Return Type:
        None

    """

    mp.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
    mp.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    mp.show()

def main():
    programming_languages= ["Java", "Python", "PHP", "JavaScript", "C#", "C++"]
    popularity= [22.2, 17.6, 8.8, 8, 7.7, 6.7]
    createChart(programming_languages,popularity)

if __name__=="__main__":
    main()

# %% [markdown]
# 2. Write a Python programming to create a pie chart with a title of the popularity of programming
# Languages.

# %%
def createChart(labels,sizes):

    """

    Description:
        Creates and displays a pie chart based on the given labels and sizes.
    Parameters:
        labels (list of str): A list of labels for each slice of the pie chart.
        sizes (list of float): A list of sizes corresponding to each label, typically representing proportions or percentages.
    Return Type:
        None
        
    """

    mp.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
    mp.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    mp.title("Programming Language Popularity")
    mp.show()

def main():
    programming_languages= ["Java", "Python", "PHP", "JavaScript", "C#", "C++"]
    popularity= [22.2, 17.6, 8.8, 8, 7.7, 6.7]
    createChart(programming_languages,popularity)

if __name__=="__main__":
    main()

# %% [markdown]
# 3 . Write a Python programming to create a pie chart of gold medal achievements of five most
# successful countries in 2016 Summer Olympics. Read the data from a csv file.

# %%
def display_medal_achivers(label,sizes):

    """

    Description:
        Creates and displays a pie chart based on the given labels and sizes.
    Parameters:
        labels (list of str): A list of labels for each slice of the pie chart.
        sizes (list of float): A list of sizes corresponding to each label, typically representing proportions or percentages.
    Return Type:
        None
        
    """

    mp.pie(sizes, labels=label, autopct='%1.1f%%')
    mp.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    mp.title("Gold Medal Achivers")
    mp.show()

def read_csv_file(file_name):
     datas=pd.read_csv(file_name)
     return  datas

def main():
    datas=read_csv_file('medal.csv')
    labels = datas['country']
    sizes = datas['gold_medal']
    display_medal_achivers(labels,sizes)

if __name__=="__main__":
    main()
